# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshipedamallu/FMML-LABS/blob/main/8module_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-22 11:53:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   204MB/s    in 0.3s
#
# 2025-04-22 11:53:56 (204 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 4447 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18956   1301.3873v1  We apply the principle of maximum entropy to s...    cs
# 27832  1704.06693v2  In this paper, we propose a novel face synthes...    cs
# 76     1607.02467v2  We introduce LL-RNNs (Log-Linear RNNs), an ext...    cs
# 21709   1001.1557v2  We study graph estimation and density estimati...  stat
# 24234   1008.3798v1  Human ovarian reserve is defined by the popula...    cs
# ...             ...                                                ...   ...
# 31229  1802.07800v2  The need for CT scan analysis is growing for p...    cs
# 19416   0810.0156v1  Most works related to unithood were conducted ...    cs
# 7787   1803.03877v1  Class-imbalance refers to classification probl...  stat
# 22569  1701.02301v2  We propose a generic framework based on a new ...  stat
# 26072  1608.05246v1  Face recognition approaches that are based on ...    cs
#
#                                                    title  year  \
# 18956              Credal Networks under Maximum Entropy  2013
# 27832  SREFI: Synthesis of Realistic Example Face Images  2017
# 76     Log-Linear RNNs: Towards Recurrent Neural Netw...  2016
# 21709                          Forest Density Estimation  2010
# 24234  Proliferating cell nuclear antigen (PCNA) allo...  2010
# ...                                                  ...   ...
# 31229  Liver segmentation in CT images using three di...  2018
# 19416  Determining the Unithood of Word Sequences usi...  2008
# 7787   On dynamic ensemble selection and data preproc...  2018
# 22569  A Universal Variance Reduction-Based Catalyst ...  2017
# 26072  How Image Degradations Affect Deep CNN-based F...  2016
#
#                                                 keywords
# 18956  [principle, probability, distribution, probabi...
# 27832  [synthesis, arbitrarily, synthetic, synthetic,...
# 76     [introduce, extension, recurrent, conceptually...
# 21709  [estimation, estimation, dimensions, estimator...
# 24234  [population, nongrowing, follicles, estimation...
# ...                                                  ...
# 31229  [diagnosis, abdominal, automatic, segmentation...
# 19416  [conducted, determination, consequently, indep...
# 7787   [imbalance, classification, instances, availab...
# 22569  [framework, stochastic, algorithm, acceleratin...
# 26072  [recognition, approaches, convolutional, domin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18956    [principle, probability, distribution, probabi...
# 27832    [synthesis, arbitrarily, synthetic, synthetic,...
# 76       [introduce, extension, recurrent, conceptually...
# 21709    [estimation, estimation, dimensions, estimator...
# 24234    [population, nongrowing, follicles, estimation...
#                                ...
# 22153    [arbitrary, linearities, mathematically, equiv...
# 2542     [expressive, tractable, hierarchical, graphica...
# 29313    [accumulation, histopathological, increased, d...
# 31524    [accelerate, performance, registration, arbitr...
# 4917     [investigates, kleinbergs, clustering, functio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8763 words.
# Out of those 4583 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="92c60e79-5d7f-450a-bfc4-ac2802e1c0a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92c60e79-5d7f-450a-bfc4-ac2802e1c0a0")) {                    Plotly.newPlot(                        "92c60e79-5d7f-450a-bfc4-ac2802e1c0a0",                        [{"x":["probability","principle","coincides","distributions","application","sequentially","specified","generally","sequential","conditional","especially","equivalent","distribution","participants","synthetic","synthesis","uniqueness","performance","augmented","represented","recognition","identities","challenging","realistic","arbitrarily","recognize","experiments","complications","containing","stability","conducted","extremely","strengths","requiring","important","representation","recurrent","motivating","perplexity","morphological","advantages","combinations","inclusion","complementary","components","attributes","contribute","component","dynamically","exploiting","incorporate","conceptually","modelling","knowledge","according","extension","introduce","combination","characteristics","structure","approximation","simulated","procedure","complexity","practical","estimates","undirected","estimation","inequality","parameter","bivariate","univariate","structured","microarray","estimator","consistency","graphical","resulting","estimating","restricted","alternative","splitting","algorithm","marginals","corresponds","dimensions","estimators","selection","techniques","replicate","computational","microscopic","microscope","estimated","conservative","automated","demonstrate","identification","examination","hematoxylin","immunohistochemistry","involving","populations","automatic","population","enumeration","viability","benchmark","integrated","likelihood","generalization","classification","processes","stochastic","factorization","subsequences","properties","dimension","computationally","different","implementation","multivariate","observations","parameters","autoregressive","generalized","efficient","considered","arbitrary","extractive","specifically","expectation","consequent","including","unsupervised","violation","summarization","alignment","individual","distilled","improvement","discriminative","disparity","challenges","intrinsic","convolutional","representations","parametric","statistics","synthesise","spatiotemporal","valuation","valuations","minimization","represent","computation","operations","objective","optimization","conditions","maximization","describes","description","variables","functions","information","marginalization","described","programming","representing","framework","outperform","approaches","combining","companies","probabilistic","kernelized","scalability","prediction","mechanisms","historical","transform","predictor","advertisement","regularized","regression","profitable","available","positions","distributed","investigate","evaluation","cooperative","sophisticated","difficult","capabilities","simplifies","reinforcement","approximate","observability"],"y":[185,52,2,115,241,21,30,60,80,93,110,50,219,18,151,41,6,869,48,93,349,8,288,58,20,44,620,2,33,24,80,52,21,32,349,374,143,5,7,24,71,27,6,38,87,64,23,108,25,81,55,16,43,332,99,73,327,150,83,307,115,45,119,212,141,81,17,213,11,113,2,5,107,2,31,55,60,160,68,62,99,12,843,5,23,40,14,149,398,6,278,7,3,57,4,98,570,109,7,3,2,57,15,188,49,1,10,212,63,55,110,504,100,119,27,2,228,57,95,755,150,20,79,240,9,58,392,123,92,5,175,24,6,229,151,6,22,45,101,2,136,95,9,108,46,373,243,49,54,2,22,6,2,75,112,128,65,174,314,125,28,87,58,108,197,661,7,76,131,64,558,98,450,106,8,168,9,35,228,42,24,61,15,3,43,114,3,285,24,94,159,241,12,27,143,47,10,136,104,10],"type":"bar"},{"x":["probability","principle","coincides","distributions","applicati ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4583,), (4583, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
 def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.6521739130434783);'>Vocabulary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Strategies</span> <span style=''>for</span> <span style=''>Neural</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.84375);'>Translation</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classical</span> <span style='background-color:rgba(0, 255, 0, 0.84375);'>translation</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>constrain</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style=''>possible</span> <span style=''>outputs</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.84375);'>translation</span> <span style=''>rules</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>input</span> <span style=''>sentence</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.4054054054054053);'>improving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.84375);'>translation</span> <span style=''>models</span> <span style=''>adopted</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>strategy</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricting</span> <span style=''>the</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.6521739130434783);'>vocabulary</span> <span style=''>to</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>likely</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555555);'>candidates</span> <span style=''>given</span> <span style=''>the</span> <span style=''>source</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3921568627450979);'>experiment</span> <span style=''>with</span> <span style=''>context</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>extend</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>examining</span> <span style=''>speed</span> <span style=''>and</span> <span style=''>accuracy</span> <span style=''>trade</span> <span style=''>offs</span> <span style=''>in</span> <span style=''>more</span> <span style=''>detail</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>decoding</span> <span style=''>time</span> <span style=''>on</span> <span style=''>CPUs</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reduced</span> <span style=''>by</span> <span style=''>up</span> <span style=''>to</span> <span style=''>90</span> <span style=''>and</span> <span style=''>training</span> <span style=''>time</span> <span style=''>by</span> <span style=''>25</span> <span style=''>on</span> <span style=''>the</span> <span style=''>WMT15</span> <span style=''>English</span> <span style=''>German</span> <span style=''>and</span> <span style=''>WMT16</span> <span style=''>English</span> <span style=''>Romanian</span> <span style=''>tasks</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bipartite</span> <span style=''>Ranking</span> <span style=''>a</span> <span style=''>Wavelet</span> <span style=''>Based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Filtering</span> <span style=''>Approach</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>the</span> <span style=''>main</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>article</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bipartite</span> <span style=''>ranking</span> <span style=''>issue</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>(FDA)</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>training</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>realizations</span> <span style=''>of</span> <span style=''>a</span> <span style=''>(possibly</span> <span style=''>sampled)</span> <span style=''>second</span> <span style=''>order</span> <span style=''>random</span> <span style=''>function</span> <span style=''>with</span> <span style=''>a</span> <span style=''>(locally)</span> <span style=''>smooth</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autocorrelation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>to</span> <span style=''>which</span> <span style=''>a</span> <span style=''>binary</span> <span style=''>label</span> <span style=''>is</span> <span style=''>randomly</span> <span style=''>assigned</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>scoring</span> <span style=''>function</span> <span style=''>s</span> <span style=''>with</span> <span style=''>optimal</span> <span style=''>ROC</span> <span style=''>curve</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>linearnonlinear</span> <span style=''>wavelet</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>it</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>how</span> <span style=''>to</span> <span style=''>select</span> <span style=''>compact</span> <span style=''>finite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>curves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptively</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>build</span> <span style=''>accurate</span> <span style=''>ranking</span> <span style=''>rules</span> <span style=''>using</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ranking</span> <span style=''>problem</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>data</span> <span style=''>with</span> <span style=''>binary</span> <span style=''>feedback</span> <span style=''>Beyond</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Improved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>in</span> <span style=''>Time</span> <span style=''>Varying</span> <span style=''>Models</span> <br/><br/><span style=''>Locally</span> <span style=''>adapted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterizations</span> <span style=''>of</span> <span style=''>a</span> <span style=''>model</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>locally</span> <span style=''>weighted</span> <span style=''>regression)</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>but</span> <span style=''>often</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>high</span> <span style=''>variance</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>reducing</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.34299516908212563);'>estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformed</span> <span style=''>space</span> <span style=''>for</span> <span style=''>the</span> <span style=''>model</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>locally</span> <span style=''>adapted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterizations</span> <span style=''>in</span> <span style=''>this</span> <span style=''>new</span> <span style=''>space</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>that</span> <span style=''>captures</span> <span style=''>this</span> <span style=''>idea</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>it</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>context</span> <span style=''>of</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>models</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>bases</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5172413793103449);'>approximating</span> <span style=''>a</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>sparse</span> <span style=''>network</span> <span style=''>each</span> <span style=''>learned</span> <span style=''>basis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constitutes</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>archetypal</span> <span style=''>sparse</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>driven</span> <span style=''>bases</span> <span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Voice</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conversion</span> <span style=''>from</span> <span style=''>Non</span> <span style=''>parallel</span> <span style=''>Corpora</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Auto</span> <span style=''>encoder</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>flexible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conversion</span> <span style=''>(SC)</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>facilitates</span> <span style=''>training</span> <span style=''>with</span> <span style=''>unaligned</span> <span style=''>corpora</span> <span style=''>Many</span> <span style=''>SC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frameworks</span> <span style=''>require</span> <span style=''>parallel</span> <span style=''>corpora</span> <span style=''>phonetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignments</span> <span style=''>or</span> <span style=''>explicit</span> <span style=''>frame</span> <span style=''>wise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correspondence</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conversion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>or</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthesizing</span> <span style=''>a</span> <span style=''>target</span> <span style=''>spectrum</span> <span style=''>with</span> <span style=''>the</span> <span style=''>aid</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignments</span> <span style=''>However</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>gravely</span> <span style=''>limit</span> <span style=''>the</span> <span style=''>scope</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>SC</span> <span style=''>due</span> <span style=''>to</span> <span style=''>scarcity</span> <span style=''>or</span> <span style=''>even</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unavailability</span> <span style=''>of</span> <span style=''>parallel</span> <span style=''>corpora</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>SC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>auto</span> <span style=''>encoder</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>non</span> <span style=''>parallel</span> <span style=''>corpora</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprises</span> <span style=''>an</span> <span style=''>encoder</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>speaker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>phonetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>and</span> <span style=''>a</span> <span style=''>decoder</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>to</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10341113105924596)
# 	representation (0.13429084380610412)
# 	information (0.23734290843806105)
# 	segmentation (0.07432675044883304)
# 	architecture (0.09766606822262118)
# 	experimental (0.13895870736086177)
# 	detection (0.11956912028725314)
# 	different (0.2710951526032316)
# 	recognition (0.1253141831238779)
# 	convolutional (0.1339317773788151)
#
# Some Statistics words are:
# 	algorithm (0.3965260545905707)
# 	statistical (0.15632754342431762)
# 	stochastic (0.13895781637717122)
# 	estimation (0.17468982630272953)
# 	variables (0.13895781637717122)
# 	theoretical (0.15781637717121588)
# 	distribution (0.18312655086848637)
# 	dimensional (0.18114143920595532)
# 	inference (0.19801488833746897)
# 	regression (0.1890818858560794)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4eb2fa1e-9867-4f3f-842e-f5d763fa364e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4eb2fa1e-9867-4f3f-842e-f5d763fa364e")) {                    Plotly.newPlot(                        "4eb2fa1e-9867-4f3f-842e-f5d763fa364e",                        [{"x":["probability","principle","coincides","distributions","application","sequentially","specified","generally","sequential","conditional","especially","equivalent","distribution","participants","synthetic","synthesis","uniqueness","performance","augmented","represented","recognition","identities","challenging","realistic","arbitrarily","recognize","experiments","complications","containing","stability","conducted","extremely","strengths","requiring","important","representation","recurrent","motivating","perplexity","morphological","advantages","combinations","inclusion","complementary","components","attributes","contribute","component","dynamically","exploiting","incorporate","conceptually","modelling","knowledge","according","extension","introduce","combination","characteristics","structure","approximation","simulated","procedure","complexity","practical","estimates","undirected","estimation","inequality","parameter","bivariate","univariate","structured","microarray","estimator","consistency","graphical","resulting","estimating","restricted","alternative","splitting","algorithm","marginals","corresponds","dimensions","estimators","selection","techniques","replicate","computational","microscopic","microscope","estimated","conservative","automated","demonstrate","identification","examination","hematoxylin","immunohistochemistry","involving","populations","automatic","population","enumeration","viability","benchmark","integrated","likelihood","generalization","classification","processes","stochastic","factorization","subsequences","properties","dimension","computationally","different","implementation","multivariate","observations","parameters","autoregressive","generalized","efficient","considered","arbitrary","extractive","specifically","expectation","consequent","including","unsupervised","violation","summarization","alignment","individual","distilled","improvement","discriminative","disparity","challenges","intrinsic","convolutional","representations","parametric","statistics","synthesise","spatiotemporal","valuation","valuations","minimization","represent","computation","operations","objective","optimization","conditions","maximization","describes","description","variables","functions","information","marginalization","described","programming","representing","framework","outperform","approaches","combining","companies","probabilistic","kernelized","scalability","prediction","mechanisms","historical","transform","predictor","advertisement","regularized","regression","profitable","available","positions","distributed","investigate","evaluation","cooperative","sophisticated","difficult","capabilities","simplifies","reinforcement","approximate","observability","evaluated","decisions","maintaining","accomplish","perceptrons","multilayer","methodology","algorithms","measuring","identifying","instances","filtering","weighting","individually","initially","significant","backpropagation","detrimental","beneficial","continuous","behaviour","timestamped","automatically","experimental","trajectories","trajectory","destination","clustering","locations","transportation","conveniently","inference","effectively","destinations","therefore","meanwhile","beforehand","inferring","supplement","effectiveness","introduced","behaviors","providers","imbalanced","potential","individuals","optimized","equations","introduces","validated","connectionist","constructed","connection","numerical","propagat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	minimizers
# 	optionally
# 	reseeding
# 	smoothers
# 	effortlessly
# 	archetypes
# 	timeliness
# 	centering
# 	illustrations
# 	continuation
# 	boundedness
# 	permissible
# 	multiplayer
# 	blockwise
# 	rehabilitation
# 	supernova
# 	collinearity
# 	consonants
# 	fluctuation
# 	ellipsoid
# Some words which never appear in Statistics papers:
# 	microscope
# 	hematoxylin
# 	immunohistochemistry
# 	extractive
# 	valuation
# 	valuations
# 	connectionist
# 	diophantine
# 	validates
# 	naturalness
# 	perceiving
# 	visuomotor
# 	misbehave
# 	hybridization
# 	magnification
# 	nanometer
# 	posedness
# 	conventionally
# 	sensation
# 	sensations

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0832793759442546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
